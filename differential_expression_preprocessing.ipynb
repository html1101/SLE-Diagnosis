# %%
# Imports
import pandas as pd # Used to analyze the contents of the datasets.
import os # Used to find the files in ../data.
import seaborn as sns # Used for data visualization.
sns.set_theme(style="darkgrid")

# %% [markdown]
# **(1)** Load Data from ../data.

# %%
# a) Find files in ../data.
path = "../data"
files = os.listdir(path)

# Make sure we have at least 1 file to analyze.
assert len(files) >= 1, "Error: Not enough files to analyze!"

# b) Read contents of each file.
contents = pd.read_excel(F"{path}/{files[0]}")
contents = contents.set_index("Unnamed: 0")
for i, filename in enumerate(files[1:]):
    print(F"Reading contents of file {path}/{filename}")
    content = pd.read_excel(F"{path}/{filename}")

    # Create a large concatenated file containing all our files. Might remove genes like A1CF that not all datasets have expression data for.
    contents = contents.join(content.set_index("Unnamed: 0"), on="Unnamed: 0", how="left").dropna(axis=0, how="any")

contents
# Out:
# Reading contents of file ../data/GSE10325 Myeloid cells_DiffExpr_Results.xls
# Reading contents of file ../data/GSE10325 T cells_DiffExpr_Results.xls
# Reading contents of file ../data/GSE110169 SLE_DiffExpr_Results.xls
# Reading contents of file ../data/GSE110174_DiffExpr_Results.xls
# Reading contents of file ../data/GSE11907 SLE GPL96_DiffExpr_Results.xls
# Reading contents of file ../data/GSE124939_DiffExpr_Results.xls
# Reading contents of file ../data/GSE13887_DiffExpr_Results.xls
# Reading contents of file ../data/GSE24706_DiffExpr_Results.xls
# Reading contents of file ../data/GSE30153_DiffExpr_Results.xls
# Reading contents of file ../data/GSE38351 SLE GPL96_DiffExpr_Results.xls
# Reading contents of file ../data/GSE50772_DiffExpr_Results.xls
# Reading contents of file ../data/GSE61635_DiffExpr_Results.xls
# Reading contents of file ../data/GSE65391_DiffExpr_Results.xls
# Reading contents of file ../data/GSE72509_DiffExpr_Results.xls
# Reading contents of file ../data/GSE80183_DiffExpr_Results.xls
# Reading contents of file ../data/GSE82221 GPL10558_DiffExpr_Results.xls
#             GSM260887  GSM260890  GSM260892  GSM260895  GSM260898  GSM260901  \
# Unnamed: 0
# AAMP         7.987898   8.146919   7.872645   7.597145   7.869418   7.444805
# AAR2         8.200976   8.173634   8.092444   8.232831   8.162719   8.381002
# AARS         9.245106   9.191260   8.986071   8.918300   9.207463   9.268225
# AASDHPPT     7.520883   6.788238   6.575260   7.036747   7.508357   7.777682
# AATF         8.703046   8.915998   8.274914   8.792234   8.887310   8.809920
# ...               ...        ...        ...        ...        ...        ...
# ZSCAN32      7.164279   7.165870   7.246966   7.115276   6.924431   7.053697
# ZSWIM8       6.506561   6.879131   7.336054   6.974795   5.767546   5.764456
# ZXDC         7.895829   7.627829   7.018347   7.375847   8.238326   8.458064
# ZYX          7.004850   7.322717   7.906336   8.073288   6.726512   6.449532
# ZZEF1        6.012135   6.358626   6.564837   6.189935   5.747853   5.836747
#
#             GSM260904  GSM260907  GSM260910  GSM260915  ...  \
# Unnamed: 0                                              ...
# AAMP         8.061699   7.710792   8.071035   7.879941  ...
# AAR2         8.054371   8.047274   8.136662   8.129697  ...
# AARS         9.199175   9.253299   9.036789   9.088280  ...
# AASDHPPT     8.008363   7.840830   6.934142   7.570956  ...
# AATF         8.405534   8.165832   8.665352   8.768472  ...
# ...               ...        ...        ...        ...  ...
# ZSCAN32      6.918531   6.969792   7.182219   7.075128  ...
# ZSWIM8       6.070139   5.830443   6.533614   6.444665  ...
# ZXDC         7.630709   7.715188   7.934763   7.740201  ...
# ZYX          6.702146   7.016427   7.966698   6.995969  ...
# ZZEF1        6.444139   6.213859   5.984934   5.890880  ...
#
#             GSM2159874_GSM2186713  GSM2159875_GSM2186714  \
# Unnamed: 0
# AAMP                     7.706938               6.988278
# AAR2                     9.265841               8.674259
# AARS                    10.414229              10.730855
# AASDHPPT                 8.514694               8.001638
# AATF                     8.646712               8.836878
# ...                           ...                    ...
# ZSCAN32                  8.936343               8.595110
# ZSWIM8                   8.885271               9.064544
# ZXDC                     6.579478               6.903806
# ZYX                     10.848133              11.308139
# ZZEF1                    9.841769               9.607057
#
#             GSM2159876_GSM2186715  GSM2159877_GSM2186716  \
# Unnamed: 0
# AAMP                     7.735954               6.546169
# AAR2                     9.007166               8.954978
# AARS                    10.750850              10.874624
# AASDHPPT                 8.384378               9.119604
# AATF                     8.937474               8.409900
# ...                           ...                    ...
# ZSCAN32                  8.542057               8.930000
# ZSWIM8                   8.282370               9.125560
# ZXDC                     6.704035               6.123917
# ZYX                     10.728937              10.344253
# ZZEF1                    9.693820               9.459928
#
#             GSM2159878_GSM2186717  GSM2159879_GSM2186718  \
# Unnamed: 0
# AAMP                     6.381689               6.501416
# AAR2                     8.511553               8.557573
# AARS                    10.770068               9.892971
# AASDHPPT                 8.370917               8.211381
# AATF                     8.654601               8.622416
# ...                           ...                    ...
# ZSCAN32                  8.044748               6.907201
# ZSWIM8                   9.027318               8.699951
# ZXDC                     6.645395               6.257242
# ZYX                     10.636688              10.679916
# ZZEF1                    9.279825               9.315709
#
#             GSM2159880_GSM2186719  GSM2159881_GSM2186720  \
# Unnamed: 0
# AAMP                     6.448938               7.624701
# AAR2                     8.656798               8.830969
# AARS                    10.443322              10.225672
# AASDHPPT                 8.209006               8.180443
# AATF                     9.108593               8.943129
# ...                           ...                    ...
# ZSCAN32                  8.534103               8.306572
# ZSWIM8                   9.460827               9.210849
# ZXDC                     6.710593               6.748697
# ZYX                     10.348836              11.051563
# ZZEF1                    9.736635               9.853272
#
#             GSM2159882_GSM2186721  GSM2159883_GSM2186722
# Unnamed: 0
# AAMP                     6.814338               7.460934
# AAR2                     8.607525               9.414040
# AARS                    10.087484              10.358513
# AASDHPPT                 8.462781               8.721967
# AATF                     8.857860               8.728813
# ...                           ...                    ...
# ZSCAN32                  8.378163               8.841689
# ZSWIM8                   8.658267               7.929616
# ZXDC                     6.597415               6.092526
# ZYX                     10.665470              10.331129
# ZZEF1                    9.647152               9.181147
#
# [4911 rows x 1169 columns]

# %%
# Convert to large excel file so we don't need to load each one of them every time we want to load this data.
contents.to_excel("differential_expression_remove.xlsx")
